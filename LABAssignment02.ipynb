# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeshbabar/DSBDALab/blob/main/LABAssignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
print(df)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0           67             84             62               90            2018
# 1           61             86             66               93            2021
# 2           70             80             70               88            2018
# 3           67             76             70               85            2018
# 4           68             84             78               84            2020
# 5           65             80             79               76            2018
# 6           79             79             73               91            2021
# 7           68             77             68               84            2019
# 8           69             86             80               70            2020
# 9           63             91             63               85            2019
# 10          67             85             60               82            2021
# ...

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
df.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df.dropna()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0           67             84             62               90            2018
# 1           61             86             66               93            2021
# 2           70             80             70               88            2018
# 3           67             76             70               85            2018
# 4           68             84             78               84            2020
# 5           65             80             79               76            2018
# 6           79             79             73               91            2021
# 7           68             77             68               84            2019
# 8           69             86             80               70            2020
# 9           63             91             63               85            2019
# 10          67             85             60               82            2021
# ...

# %%
col = ['Math_Score', 'Reading_Score' , 'Writing_Score','Placement_Score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['Math_Score']>90))
print(np.where(df['Reading_Score']<25))
print(np.where(df['Writing_Score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
df['Math_Score'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Z Selection

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['Math_Score']))
print(z)
# Out:
# 0     0.215145
# 1     1.321608
# 2     0.338086
# 3     0.215145
# 4     0.030735
# 5     0.583966
# 6     1.997779
# 7     0.030735
# 8     0.153675
# 9     0.952787
# 10    0.215145
# 11    1.260137
# 12    1.321608
# 13    0.583966
# 14    0.583966
# 15    0.583966
# 16    1.137197
# 17    1.813368
# 18    0.768376
# 19    1.444548
# 20    0.706906
# 21    0.952787
# 22    0.952787
# 23    1.506018
# 24    0.891317
# 25    0.891317
# 26    0.952787
# 27    1.075727
# 28    1.444548
# 29    0.891317
# Name: Math_Score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z < threshold)
print(sample_outliers)
# Out:
# (array([4, 7, 8]),)

# %% [markdown]
# # **Inter** Quartile Range

# %%
sorted_rscore=sorted(df['Reading_Score'])

# %%
print(sorted_rscore)
# Out:
# [76, 76, 77, 79, 80, 80, 82, 82, 82, 83, 83, 84, 84, 84, 85, 85, 86, 86, 86, 86, 87, 87, 88, 91, 91, 92, 93, 93, 94, 95]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 82.0 87.75

# %%
IQR=q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 73.375 96.375

# %%
r_outliers = []
for i in sorted_rscore:
    if (i< lwr_bound or i > upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %% [markdown]
# # Scatterplots

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement_Score'], df['Writing_Score'])
